# %% [markdown]
# <a href="https://colab.research.google.com/github/avi2362/Avi/blob/main/ML_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## *Project - 1*
#
# ## FACE RECOGNITION USING PRINCIPAL COMPONENT ANALYSIS
#
# ### Made by : Avinash reddy Vasipalli
# ### Reg. No.: RA1911027010007
# ### Subject : Machine Learning
# ### Sub Code: 18CSE392T
# ### Branch  : Computer Science Engineering Big Data
# ### Dated   : 24th September, 2021

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (25,9)

# %%
url = 'https://raw.githubusercontent.com/avi2362/Avi/main/Face.csv'
df = pd.read_csv(url,error_bad_lines=False)
df.head(10)
# Out:
#           0         1         2         3  ...      4093      4094      4095  target
# 0  0.309917  0.367769  0.417355  0.442149  ...  0.152893  0.161157  0.157025       0
# 1  0.454545  0.471074  0.512397  0.557851  ...  0.152893  0.152893  0.152893       0
# 2  0.318182  0.400826  0.491736  0.528926  ...  0.140496  0.148760  0.152893       0
# 3  0.198347  0.194215  0.194215  0.194215  ...  0.752066  0.752066  0.739669       0
# 4  0.500000  0.545455  0.582645  0.623967  ...  0.177686  0.173554  0.173554       0
# 5  0.549587  0.545455  0.541322  0.537190  ...  0.714876  0.706612  0.702479       0
# 6  0.330578  0.305785  0.330578  0.351240  ...  0.144628  0.152893  0.152893       0
# 7  0.128099  0.185950  0.247934  0.314050  ...  0.152893  0.173554  0.173554       0
# 8  0.243802  0.297521  0.367769  0.454545  ...  0.190083  0.181818  0.190083       0
# 9  0.380165  0.442149  0.483471  0.545455  ...  0.173554  0.173554  0.173554       0
#
# [10 rows x 4097 columns]

# %%
p,q = df.shape 
print("Number of data items (faces) in dataset =",p)
print("Number of attributes in the dataset     =",q)
# Out:
# Number of data items (faces) in dataset = 400
# Number of attributes in the dataset     = 4097

# %%
df.describe().T
# Out:
#         count       mean        std  ...        50%        75%        max
# 0       400.0   0.400134   0.180695  ...   0.392562   0.528926   0.805785
# 1       400.0   0.434236   0.189504  ...   0.458678   0.575413   0.822314
# 2       400.0   0.476281   0.194742  ...   0.512397   0.636364   0.871901
# 3       400.0   0.518481   0.193313  ...   0.545455   0.666322   0.892562
# 4       400.0   0.554845   0.188593  ...   0.584711   0.702479   0.871901
# ...       ...        ...        ...  ...        ...        ...        ...
# 4092    400.0   0.335909   0.195280  ...   0.299587   0.462810   0.921488
# 4093    400.0   0.321415   0.187842  ...   0.289256   0.446281   0.929752
# 4094    400.0   0.313647   0.183616  ...   0.270661   0.414256   0.884298
# 4095    400.0   0.310455   0.180635  ...   0.272727   0.417355   0.822314
# target  400.0  19.500000  11.557853  ...  19.500000  29.250000  39.000000
#
# [4097 rows x 8 columns]

# %%
labels=df["target"]
labels
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 395    39
# 396    39
# 397    39
# 398    39
# 399    39
# Name: target, Length: 400, dtype: int64

# %%
pixels=df.drop(['target'],axis = 1)
pixels
# Out:
#             0         1         2  ...      4093      4094      4095
# 0    0.309917  0.367769  0.417355  ...  0.152893  0.161157  0.157025
# 1    0.454545  0.471074  0.512397  ...  0.152893  0.152893  0.152893
# 2    0.318182  0.400826  0.491736  ...  0.140496  0.148760  0.152893
# 3    0.198347  0.194215  0.194215  ...  0.752066  0.752066  0.739669
# 4    0.500000  0.545455  0.582645  ...  0.177686  0.173554  0.173554
# ..        ...       ...       ...  ...       ...       ...       ...
# 395  0.400826  0.495868  0.570248  ...  0.161157  0.157025  0.136364
# 396  0.367769  0.367769  0.351240  ...  0.487603  0.512397  0.549587
# 397  0.500000  0.533058  0.607438  ...  0.177686  0.148760  0.190083
# 398  0.214876  0.219008  0.219008  ...  0.574380  0.590909  0.603306
# 399  0.516529  0.462810  0.280992  ...  0.359504  0.355372  0.384298
#
# [400 rows x 4096 columns]

# %%
def show_orignal_images(pixels):
	fig, axes = plt.subplots(6, 10, figsize=(11, 7),
	                         subplot_kw={'xticks':[], 'yticks':[]})
	for i, ax in enumerate(axes.flat):
	    ax.imshow(np.array(pixels)[i].reshape(64, 64), cmap='gray')
	plt.show()

# %%
show_orignal_images(pixels)

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test=train_test_split (pixels,labels)

# %%
#PCA step
from sklearn.decomposition import PCA
pca=PCA(135).fit(x_train)

# %%
per_var = np.round(pca.explained_variance_ratio_*100, decimals=1)
labels = [str(x) for x in range(1,len(per_var)+1)]
 
plt.bar(x=range(1,len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.xticks(rotation=90)
plt.title('Plot of PCA based results',size=21)
plt.show()

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('Principal Components - Variance Ratio\n',size=22)
plt.show()

# %%
def show_eigenfaces(pca):
   fig, axes = plt.subplots(3, 8, figsize=(15, 7),subplot_kw={'xticks':[], 'yticks':[]})
   for i, ax in enumerate(axes.flat):
       ax.imshow(pca.components_[i].reshape(64, 64), cmap='gray')
       ax.set_title("PC " + str(i+1))
   plt.show()

show_eigenfaces(pca)

# %%
x_train_pca=pca.transform(x_train)
from time import time
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
clf=SVC(kernel="rbf",C=1000,gamma=0.01)
clf.fit(x_train_pca,y_train)
# Out:
# SVC(C=1000, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
x_test_pca=pca.transform(x_test)
y_pred=clf.predict(x_test_pca)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         4
#            7       0.00      0.00      0.00         0
#            8       1.00      1.00      1.00         2
#            9       1.00      0.67      0.80         3
#           10       1.00      1.00      1.00         3
#           11       1.00      1.00      1.00         2
#           12       1.00      1.00      1.00         1
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         3
#           15       1.00      1.00      1.00         1
#           16       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         4
#           18       1.00      1.00      1.00         3
#           19       1.00      1.00      1.00         4
#           20       1.00      1.00      1.00         5
#           21       1.00      1.00      1.00         2
#           22       0.50      1.00      0.67         1
#           23       1.00      1.00      1.00         5
#           24       1.00      1.00      1.00         3
#           25       0.00      0.00      0.00         1
#           26       1.00      1.00      1.00         5
#           27       1.00      1.00      1.00         1
#           28       1.00      1.00      1.00         1
#           29       1.00      1.00      1.00         4
#           30       1.00      1.00      1.00         4
#           31       1.00      1.00      1.00         1
#           32       1.00      1.00      1.00         3
#           33       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         1
#           35       1.00      1.00      1.00         3
#           36       1.00      1.00      1.00         3
#           37       1.00      0.80      0.89         5
#           38       1.00      1.00      1.00         3
#           39       0.00      0.00      0.00         0
#
#     accuracy                           0.97       100
#    macro avg       0.91      0.91      0.91       100
# weighted avg       0.98      0.97      0.98       100
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_pred
# Out:
# array([ 4, 21, 31,  9,  7,  4,  2, 24, 14,  9, 20, 15, 35,  6,  2, 37, 20,
#         4, 19,  5,  6, 26, 38, 20, 18, 35, 23, 19, 23, 26, 19, 12, 30, 27,
#        11, 26, 22, 39, 36,  0, 38, 14,  3,  6, 32, 32, 17, 36,  1, 14, 18,
#        26, 24, 19, 17, 37, 34, 29,  5, 32,  0, 37, 24,  8,  3, 22,  1, 23,
#        20, 13, 20, 23, 10, 30,  0, 17, 10, 29,  8, 38, 29,  1, 30, 28, 11,
#        30, 26, 16,  6, 35, 17, 18, 10, 23, 13, 29, 33, 37, 21, 36])

# %%
show_orignal_images(x_test)

# %%
image1=df[df.target==15].drop(["target"],axis=1)

def show_orignal_images1(pixels):
  fig, axes = plt.subplots(1, 10, figsize=(11, 7), subplot_kw={'xticks':[], 'yticks':[]})
  for i, ax in enumerate(axes.flat):
    ax.imshow(np.array(pixels)[i].reshape(64, 64), cmap='gray')
  plt.show()

show_orignal_images1(image1)
